woknn_online = [4.449427127838135, 4.6988935470581055, 4.41036319732666, 4.411089897155762, 4.672290802001953, 4.892878532409668, 4.658672332763672, 4.542694091796875, 4.462130069732666, 4.700027942657471, 4.741092681884766, 4.358784198760986, 5.0719428062438965, 4.916569232940674, 4.730539321899414, 4.719173431396484, 4.8146071434021, 4.653841972351074, 4.754930019378662, 4.782139778137207, 4.862919330596924, 4.709400653839111, 4.852546215057373, 4.9351654052734375, 5.104764938354492, 4.559291362762451, 4.777766704559326, 4.771130084991455, 4.940354824066162, 4.526152610778809, 4.52854585647583, 5.354406833648682, 4.928700923919678, 4.501107215881348, 4.775516986846924, 4.950725555419922, 4.745173454284668, 4.85830545425415, 4.645267009735107, 4.455883979797363, 4.73725700378418, 5.13173246383667, 5.008930206298828, 5.2858567237854, 4.706573963165283, 4.548383712768555, 4.557765483856201, 4.6130876541137695, 4.797233581542969, 4.89347505569458, 4.703463554382324, 4.786080837249756, 4.580114841461182, 4.948266506195068, 4.766354560852051, 5.077014923095703, 5.016081809997559, 5.025122165679932, 4.693169593811035, 4.873429775238037, 5.2090888023376465, 5.1195220947265625, 5.047610759735107, 4.973726749420166, 5.337429523468018, 4.7554612159729, 4.933984756469727, 5.276020526885986, 4.864338397979736, 4.771181583404541, 4.957503318786621, 4.84461784362793, 5.059290409088135, 5.054469585418701, 5.2691545486450195, 5.634454250335693, 4.783176422119141, 4.914562225341797, 4.939594745635986, 5.11767053604126, 4.753445148468018, 4.9637603759765625, 4.71199369430542, 5.039672374725342, 4.548120498657227, 4.422758102416992, 4.691265106201172, 4.7083210945129395, 4.663880348205566, 4.405325889587402, 4.769415378570557, 4.8653340339660645, 5.129763603210449, 5.341777324676514, 4.994881629943848, 4.991423606872559, 4.505621433258057, 4.822535991668701, 4.853329181671143, 4.923648357391357]

# %%
baseline = np.array(baseline)
baseline_online = np.array(baseline_online)
residual_mlp = np.array(residual_mlp)
residual_mlp_online = np.array(residual_mlp_online)
woknn = np.array(woknn)
woknn_online = np.array(woknn_online)

# %%
# Plotting
plt.figure(figsize=(8, 6))

plt.plot(timesteps, baseline/10, label='Vanilla MLP', color='C0', linewidth=2)
plt.plot(timesteps, baseline_online/10, label='Vanilla MLP (OC)', linestyle='--', color='C0', linewidth=2)
plt.plot(timesteps, residual_mlp/10, label='Residual MLP', color='C1', linewidth=2)
plt.plot(timesteps, residual_mlp_online/10, label='Residual MLP (OC)', linestyle='--', color='C1', linewidth=2)
plt.plot(timesteps, woknn/10, label='WOKNN', color='C2', linewidth=2)
plt.plot(timesteps, woknn_online/10, label='WOKNN (OC)', linestyle='--', color='C2', linewidth=2)

# plt.title('Model Positioning Error Over Time')
# plt.xlabel('Time (Hours)')
# plt.ylabel('Positioning Error (cm)')
plt.legend(fontsize=24)
plt.grid(True)
# Change font size
# plt.title('Model Positioning Error Over Time', fontsize=14)
plt.xlabel('Time (Hours)', fontsize=28)
plt.ylabel('Positioning Error (cm)', fontsize=28)
plt.ylim(bottom=0, top=20)
plt.xlim(left=0, right=100000)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0), useMathText=True)
plt.gca().xaxis.get_offset_text().set_fontsize(20)
plt.gca().xaxis.get_major_ticks()[0].label1.set_visible(False)
plt.gca().xaxis.get_major_ticks()[0].tick1line.set_visible(False)
plt.tight_layout()
plt.gcf().subplots_adjust(right=0.93) 
plt.savefig('generated_figures/model_positioning_error.pdf')

# %%
# %%
plt.figure(figsize=(8, 6))

# Plotting
plt.plot(timesteps, pico_baseline/10, label='On-device model (INT8)', color='C0', linewidth=2)
plt.plot(timesteps, pico_online/10, label='On-device model (INT8) (OC)', linestyle='--', color='C0', linewidth=2)
plt.plot(timesteps, residual_mlp/10, label='Residual MLP (FP32)', color='C1', linewidth=2)
plt.plot(timesteps, residual_mlp_online/10, label='Residual MLP (FP32) (OC)', linestyle='--', color='C1', linewidth=2)

plt.xlabel('Time (Hours)', fontsize=28)
plt.ylabel('Positioning Error (cm)', fontsize=28)
plt.legend(fontsize=24)
plt.grid(True)
# Change font size
# plt.title('Model Positioning Error Over Time', fontsize=14)
plt.ylim(bottom=0, top=7.5)
plt.xlim(left=0, right=100000)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0), useMathText=True)
plt.gca().xaxis.get_offset_text().set_fontsize(20)
plt.gca().xaxis.get_major_ticks()[0].label1.set_visible(False)
plt.gca().xaxis.get_major_ticks()[0].tick1line.set_visible(False)
plt.tight_layout()
plt.savefig('generated_figures/model_positioning_error_pico.pdf')

# %%
raw_data = np.load("./dataset/heatmaps/heatmap_176/raw.npy")
old_data = np.load("./dataset/heatmaps/heatmap_176/cleaned_LAMBERTIAN-MEAN.npy")
cleaned_data = np.load("./dataset/heatmaps/heatmap_176/cleaned_LAMBERTIAN-IDW.npy")

# %%
raw_data = np.where(raw_data == -1, np.nan, raw_data)
old_data = np.where(old_data == -1, np.nan, old_data)
cleaned_data = np.where(cleaned_data == -1, np.nan, cleaned_data)

# %%
raw_led_18 = raw_data[:, :, 18].mean(axis=2)
raw_led_18 /= np.nanmax(raw_led_18)

old_led_18 = old_data[:, :, 18]
old_led_18 /= np.nanmax(old_led_18)

cleaned_led_18 = cleaned_data[:, :, 18]
cleaned_led_18 /= np.nanmax(cleaned_led_18)

raw_led_7 = raw_data[:, :, 7].mean(axis=2)
raw_led_7 /= np.nanmax(raw_led_7)

old_led_7 = old_data[:, :, 7]
old_led_7 /= np.nanmax(old_led_7)

cleaned_led_7 = cleaned_data[:, :, 7]
cleaned_led_7 /= np.nanmax(cleaned_led_7)

# %%
def plot_heatmap(data, title, filename):
    # Only plot the lower left corner
    first_nan_x = np.isnan(data).argmax(axis=0)[0]
    first_nan_y = np.isnan(data).argmax(axis=1)[0]
    data = data[:first_nan_y, :first_nan_x]
    
    plt.imshow(data, origin='lower', interpolation='nearest')
    # plt.title(title)
    plt.xlabel("x-axis (cm)", fontsize=24)
    plt.ylabel("y-axis (cm)", fontsize=24)
    # Change tick size
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
plt.figure(figsize=(8, 6))

plt.plot(timesteps, avg_decay, label="Average Decay")
plt.xlabel('Time (Hours)', fontsize=28)
plt.ylabel('Relative LED light intensity', fontsize=28)
plt.grid(True)

plt.xlim(left=0.0, right=100000)
plt.ylim(bottom=0.4, top=1)

# plt.title('Average Decay Scalar vs. Time', fontsize=14)
plt.fill_between(timesteps, min_decay, max_decay, alpha=0.2, label="Min/Max Decay")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0), useMathText=True)
plt.gca().xaxis.get_offset_text().set_fontsize(20)
plt.legend(fontsize=24)
plt.tight_layout()

plt.savefig('generated_figures/degradation_graph.pdf')

# %%
import torch
from ransac_line import fit
from models.mlp_online_pico import MLPOnlinePico

i = 0

model = MLPOnlinePico("./dataset/heatmaps/heatmap_176/cleaned_LAMBERTIAN-IDW.npy", seed=42)
model.load("./saved_runs/MLP-ONLINE-PICO-1760339628.pth")

rng = np.random.default_rng(42)
X = None
for _ in range(100):
    x = None
    while x is None or np.isnan(x).any():
        x = cleaned_data[rng.integers(0, cleaned_data.shape[0]), rng.integers(0, cleaned_data.shape[1]), :]
    X = np.vstack((X, x)) if X is not None else x

predictions = (model.predict(torch.tensor(X, dtype=torch.float32)).numpy(force=True)/10).round(0).astype(int)
outliers_mask = rng.choice([0, 1], size=predictions.shape, p=[0.8, 0.2])
predictions += rng.integers(low=20, high=30, size=predictions.shape) * outliers_mask * rng.choice([-1, 1], size=predictions.shape)
predictions = np.clip(predictions, (0, 0), (cleaned_data.shape[1] - 1, cleaned_data.shape[0] - 1))
ref_data = cleaned_data[predictions[:, 1], predictions[:, 0]]

# plot ransac line between the two
coef = fit(ref_data[:, i].astype(np.float32), X[:, i].astype(np.float32), 0.1, 25, 42)

outliers_mask = np.abs(coef * ref_data[:, i] - X[:, i]) > 0.025

plt.figure(figsize=(8, 6))

plt.scatter(ref_data[:, i], X[:, i], s=25, color='C0', label='Predicted Points')
# plt.scatter(ref_data[outliers_mask, i], X[outliers_mask, i], s=25, color='red', label='Predicted Points')

plt.plot(ref_data[:, i], coef * ref_data[:, i], color='salmon', label='RANSAC Line')

plt.xlabel("Incoming RSS", fontsize=24)
plt.ylabel("Reference RSS", fontsize=24)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.grid()
plt.savefig('generated_figures/ransac_line.pdf')

# %% [markdown]
# # Poster

# %%
plt.plot(timesteps, baseline, label="Baseline")
plt.plot(timesteps, baseline[0].repeat(100), label="Ideal performance", linestyle='--', color='C2')
plt.title('Model Positioning Error Over Time')
plt.xlabel('Time (Hours)')
plt.ylabel('Positioning Error (mm)')
plt.legend()
plt.grid(True)
# Change font size
plt.title('Model Positioning Error Over Time', fontsize=14)
plt.xlabel('Time (Hours)', fontsize=12)
plt.ylabel('Positioning Error (mm)', fontsize=12)
plt.ylim(bottom=0, top=200)
plt.xlim(left=0, right=100000)
plt.tight_layout()
plt.savefig('generated_figures/poster_degradation.pdf')

# %%
from dataset.clean import generate_score_matrix

score_matrix = generate_score_matrix(raw_data, 2, 0)
best_score_idx = score_matrix.argmin(axis=3)  # shape (y, x, led)
best_scores = np.take_along_axis(score_matrix, best_score_idx[..., np.newaxis], axis=3).squeeze(axis=3) # ...
best_data = np.take_along_axis(raw_data, best_score_idx[..., np.newaxis], axis=3).squeeze(axis=3) # ...

best_data[:, :, 29]

img = plt.imshow(score_matrix.min(axis=3)[:, :, 29], origin='lower', interpolation='nearest', vmin=0.04, vmax=0.1)
# Scatter the points score_matrix.min(axis=3)[:, :, 29] < 0.04
# plt.scatter(np.where(score_matrix.min(axis=3)[:, :, 29] > 0.04)[1], np.where(score_matrix.min(axis=3)[:, :, 29] > 0.04)[0], color='red', s=1, label='Bad Points')
plt.xlabel("x-axis (cm)", fontsize=14)
plt.ylabel("y-axis (cm)", fontsize=14)


x_target, y_target = 277, 254
plt.scatter(x_target, y_target, color='red', s=25, label='Point to clean')

# Reference points
ref_points = [
    (278, 256),
    (277, 256),
    (278, 255),
    (279, 253),
    (278, 252)
]

# Plot reference points and connecting lines
for x_ref, y_ref in ref_points:
    dist = np.hypot(x_ref - x_target, y_ref - y_target)
    weight = 1 / (dist + 1e-5)  # avoid div by zero
    linewidth = 3 * weight

    plt.scatter(x_ref, y_ref, color='green', s=10, label='Reference points' if x_ref == 278 and y_ref == 256 else "")
    plt.plot([x_target, x_ref], [y_target, y_ref], color='gray', linestyle='--', linewidth=linewidth, alpha=0.75)

plt.xlim(271, 281)
plt.ylim(250, 260)

plt.legend()
plt.title('Cleaning interpolation example for LED 29', fontsize=14)
plt.colorbar(img, label='Score (lower is better)')
plt.tight_layout()
plt.gca().set_aspect('equal')
plt.savefig('generated_figures/cleaning_interpolation_example.pdf')
# Out:
# /home/joey/Github/VLP/dataset/clean.py:49: UserWarning: 'where' used without 'out', expect unitialized memory in output. If this is intentional, use out=None.
#   refs_mean = np.divide(refs_sum, count_neighbors, where=valid_mask != 0)

# %%
def plot_heatmap_poster(data, title, filename):
    plt.imshow(data, origin='lower', interpolation='nearest')
    plt.title(title)
    plt.xlabel("x-axis (cm)", fontsize=14)
    plt.ylabel("y-axis (cm)", fontsize=14)
    plt.colorbar()
    plt.xlim(0, 120)
    plt.ylim(0, 120)
    plt.tight_layout()
    plt.savefig(f'generated_figures/{filename}')
    plt.clf()

plot_heatmap_poster(raw_led_7, "Raw Data for LED 7", 'poster_raw_led_7.png')
plot_heatmap_poster(old_led_7, "Baseline Cleaned Data for LED 7 (LAMBERTIAN-MEAN)", 'poster_old_led_7.png')
plot_heatmap_poster(cleaned_led_7, "Cleaned Data for LED 7 (LAMBERTIAN-IDW)", 'poster_cleaned_led_7.png')

# %%
led_6_predicted = np.array([1.0109997987747192, 0.9908574819564819, 0.9608626961708069, 0.9865450263023376, 1.0273072719573975, 1.0164027214050293, 1.0054689645767212, 1.013437271118164, 1.0258355140686035, 1.0037267208099365, 1.0633198022842407, 1.0522723197937012, 1.0608314275741577, 1.0485806465148926, 1.0278480052947998, 1.0389105081558228, 1.061283826828003, 1.0551749467849731, 1.05256986618042, 1.0367592573165894, 1.0763096809387207, 1.03580904006958, 1.0294753313064575, 1.0287280082702637, 1.0780268907546997, 1.0479201
645914077759, 0.6876680254936218, 0.6788688898086548, 0.6701340079307556, 0.6688506007194519, 0.6674497723579407, 0.660607099533081, 0.654466986656189, 0.6403428912162781, 0.637700080871582, 0.6350876688957214, 0.628248393535614, 0.6239849328994751, 0.6171807050704956, 0.612899899482727, 0.6119623780250549, 0.613221287727356, 0.6051065921783447, 0.5960840582847595, 0.5955905318260193, 0.5859957337379456, 0.5810350775718689, 0.5837575197219849, 0.5659734606742859, 0.5663252472877502, 0.5522477030754089, 0.5565879940986633, 0.5443742275238037, 0.5456405878067017, 0.5407472848892212, 0.5381355881690979, 0.5334039926528931, 0.5261333584785461, 0.5233827829360962, 0.5227487683296204, 0.5156344175338745, 0.5162164568901062, 0.5065013766288757, 0.5001160502433777, 0.49763381481170654, 0.4854375720024109, 0.49383223056793213, 0.4870350658893585, 0.4749385714530945, 0.4781780540943146, 0.48197928071022034, 0.47256749868392944, 0.4645644724369049, 0.4555674195289612, 0.4622398018836975, 0.45478665828704834, 0.45324069261550903, 0.4415398836135864, 0.43974363803863525, 0.4495587944984436, 0.43210744857788086])

# %%
plt.plot(timesteps, 1/led_6_predicted, label="LED 6 Predicted")
plt.plot(timesteps, led_6_ground_truth, label="LED 6 Ground Truth")

plt.title('LED 6 Degradation Factor Prediction', fontsize=14)
plt.xlabel('Time (Hours)', fontsize=12)
plt.ylabel('LED degradation factor', fontsize=12)

plt.legend()
plt.grid(True)
# Change font size
plt.xlim(left=0, right=100000)
plt.tight_layout()
plt.savefig('generated_figures/degradation_prediction_led_6.pdf')

# %%
plt.figure(figsize=(8, 6))

plt.plot(timesteps, 1/led_35_predicted, label="Predicted")
plt.plot(timesteps, led_35_ground_truth, label="Ground Truth")

# plt.title('LED 35 Degradation Factor Prediction', fontsize=14)
plt.xlabel('Time (Hours)', fontsize=28)
plt.ylabel('Relative LED light intensity', fontsize=28)

plt.xlim(left=0.0, right=100000)
plt.ylim(bottom=0.4, top=1)

plt.legend(fontsize=24)
plt.grid(True)
# Change font size
plt.xlim(left=0, right=100000)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0), useMathText=True)
plt.gca().xaxis.get_offset_text().set_fontsize(20)
plt.tight_layout()
plt.savefig('generated_figures/degradation_prediction_led_35.pdf')

# %%
cleaned_led_16 = cleaned_data[:, :, 16]
cleaned_led_16 /= np.nanmax(cleaned_led_16)

degraded_led_16 = cleaned_led_16 * 0.7

# %%
plt.imshow(cleaned_led_16, origin='lower', interpolation='nearest')
plt.title("Cleaned Data for LED 16 (LAMBERTIAN-IDW)", fontsize=14)
plt.xlabel("x-axis (cm)", fontsize=14)
plt.ylabel("y-axis (cm)", fontsize=14)
plt.colorbar()
plt.tight_layout()
plt.savefig('generated_figures/poster_cleaned_led_16.png')
plt.clf()

# %%
led_16_k = 3.4511617038824184e-06
plt.imshow(cleaned_led_16*np.exp(-led_16_k*51322), origin='lower', interpolation='nearest', vmin=0, vmax=1)
plt.title("Aged Data for LED 16 (51322 Hours)", fontsize=14)
plt.xlabel("x-axis (cm)", fontsize=14)
plt.ylabel("y-axis (cm)", fontsize=14)
plt.colorbar()
plt.tight_layout()
plt.savefig('generated_figures/poster_aged_led_16.png')
plt.show()
